# %%
import pandas as pd

# %%
pokedex = pd.read_csv(r'../../data/csv/pokedex.csv')
pokedex
# Out:
#      Unnamed: 0.1  Unnamed: 0  pokedex_number         english_name  \
# 0               0           0               1            Bulbasaur
# 1               1           1               2              Ivysaur
# 2               2           2               3             Venusaur
# 3               3           3               4           Charmander
# 4               4           4               5           Charmeleon
# ..            ...         ...             ...                  ...
# 381           381         381             382               Kyogre
# 382           382         382             383              Groudon
# 383           383         383             384             Rayquaza
# 384           384         384             385              Jirachi
# 385           385         385             386  Deoxys Normal Forme
#
#     german_name  generation            species   type_1   type_2  type_number  \
# 0       Bisasam           1       Seed Pokémon    Grass   Poison            2
# ...

# %%
pokedex.loc[ 24 ]
# Out:
# Unnamed: 0.1                     24
# Unnamed: 0                       24
# pokedex_number                   25
# english_name                Pikachu
# german_name                 Pikachu
# generation                        1
# species               Mouse Pokémon
# type_1                     Electric
# type_2                          NaN
# type_number                       1
# weight_kg                       0.6
# height_m                        0.4
# is_sub_legendary                  0
# is_legendary                      0
# is_mythical                       0
# abilities_number                  2
# ability_1                    Static
# ability_2                       NaN
# ability_hidden        Lightning Rod
# total_points                    320
# hp                               35
# attack                           55
# defense                          40
# sp_attack                        50
# sp_defense                       50
# speed                            90
# ...

# %%
pokedex.loc[ 24 ]

# %%
pokedex[pokedex['german_name'] == 'Pikachu']
# Out:
#     Unnamed: 0.1  Unnamed: 0  pokedex_number english_name german_name  \
# 24            24          24              25      Pikachu     Pikachu
#
#     generation        species    type_1 type_2  type_number  ...  \
# 24           1  Mouse Pokémon  Electric    NaN            1  ...
#
#     against_flying  against_psychic  against_bug  against_rock  against_ghost  \
# 24             0.5              1.0          1.0           1.0            1.0
#
#     against_dragon against_dark against_steel against_fairy    japanese_name
# 24             1.0          1.0           0.5           1.0  ピカチュウ (Pikachu)
#
# [1 rows x 54 columns]
